# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd
import edhec_risk_kit as erk

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # GBM interactive plots

# %%
erk.gbm(10,100, mu=0.1).plot(legend=False)
# Out:
# <AxesSubplot: >

# %%
def show_gbm(n_scenarios, mu, sigma):
    '''
    
    '''
    s_0=100
    prices = erk.gbm(n_scenarios=n_scenarios, mu=mu, sigma=sigma, s_0=s_0)
    ax = prices.plot(legend=False, color="indianred", alpha=0.5, linewidth=2, figsize=(12,5))
    ax.axhline(y=s_0, ls=":", color="black")
    ax.set_ylim(top=400)
    ax.plot(0,s_0, marker='o',color="darkred", alpha=0.2)

# %%
show_gbm(30,0.07, 0.15)

# %%
gbm_control = widgets.interactive(show_gbm, n_scenarios = (1, 20, 5),
                                  mu=(0,0.2,0.01),
                                  sigma=(0,.3,.01)
                                 )

# %%
display(gbm_control)
# Out:
# interactive(children=(IntSlider(value=11, description='n_scenarios', max=20, min=1, step=5), FloatSlider(value…
