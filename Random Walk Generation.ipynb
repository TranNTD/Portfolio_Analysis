# %% [markdown]
# # Random Walk Generation

# %% [markdown]
# $$\frac{S_{t+dt}-S_{t}}{S_{t}}=\mu dt+\sigma\sqrt{dt}\xi_{t}$$

# %%
import numpy as np
import pandas as pd


def gbm0(n_years=10, n_scenarios=100, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    '''
    Evolution of a Stock Pricing using a Geometric Brownian Motion Model
    xi is random normal
    '''
    
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios)) # generate matrix which has rows=steps, columns=scenarios
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    
    #to price
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
p=gbm0(n_years=10,n_scenarios=3)

# %%
p.shape
# Out:
# (120, 3)

# %%
p.head()
# Out:
#             0          1           2
# 0   97.331051  95.450844  102.933031
# 1  103.518143  98.825583  107.229543
# 2  100.230322  97.840538  106.472295
# 3  105.652445  96.419454  102.449949
# 4  108.390200  90.772840   99.488527

# %%
p.plot()
# Out:
# <AxesSubplot: >

# %%
p = gbm(n_years=10, n_scenariors=1000).plot(figsize=(12,6), legend=False)

# %%
def gbm1(n_years=10, n_scenarios=100, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    '''
    Evolution of a Stock Pricing using a Geometric Brownian Motion Model
    xi is random normal
    '''
    
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=sigma*np.sqrt(dt),size=(n_steps, n_scenarios)) # generate matrix which has rows=steps, columns=scenarios
    
    
    #to price
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
# %timeit gbm0(n_years=5, n_scenarios=1000)
# Out:
# 3.56 ms ± 845 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit gbm1(n_years=5, n_scenarios=1000)
# Out:
# 2.91 ms ± 631 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
gbm1(n_years=10, n_scenarios=20).plot(legend=False, figsize=(12,6))
# Out:
# <AxesSubplot: >

# %%
def gbm1(n_years=10, n_scenarios=100, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    '''
    Evolution of a Stock Pricing using a Geometric Brownian Motion Model
    xi is random normal
    '''
    
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=sigma*np.sqrt(dt),size=(n_steps, n_scenarios)) # generate matrix which has rows=steps, columns=scenarios
    rets_plus_1[0] = 1
    
    #to price
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
gbm1(n_years=10, n_scenarios=20).plot(legend=False, figsize=(12,6))
# Out:
# <AxesSubplot: >
